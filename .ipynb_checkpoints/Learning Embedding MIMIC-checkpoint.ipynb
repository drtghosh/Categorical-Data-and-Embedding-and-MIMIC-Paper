# %% [markdown]
# # Blood Sample Data

# %% [markdown]
# #### Importing Libraries

# %%
import time
start_time = int(time.time())
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential, Model
from keras.layers import *
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# Out:
# Using TensorFlow backend.
# /anaconda2/envs/py36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# #### Reading the Data

# %%
mimic=pd.read_csv('zevac_data.csv', sep='\t', usecols = ['patient_id', 'admission_id', 'age', 'sex', 'sc_date',
       'sample_type', 'bacteria_name', 'antibiotic_name', 'num_prev_adm',
       'interval', 'device', 'hai', 'susceptibility', 'comorbidity'])
mimic['susceptibility']=mimic['susceptibility'].replace({'I':'R'})

# %% [markdown]
# #### Getting Blood Sample Data

# %%
blood=mimic[mimic['sample_type']=='Blood'].reset_index(drop=True)

# %%
df=blood[['age', 'sex', 'num_prev_adm', 'interval', 'device', 
      'comorbidity', 'bacteria_name', 'antibiotic_name', 'susceptibility']]
df=df.drop_duplicates()
df=df.reset_index(drop=True)

# %% [markdown]
# #### Creating Training Data

# %%
train, test = train_test_split(df, test_size=0.3, random_state=0)

# %%
train.susceptibility.value_counts()
# Out:
# S    128983
# R     72274
# Name: susceptibility, dtype: int64

# %% [markdown]
# #### Shuffling Training Data

# %%
train = train.sample(frac=1).reset_index(drop=True)

# %% [markdown]
# #### Taking Out Target Column and Dropping Unnecesary Columns

# %%
train_labels = train['susceptibility']

# %%
df_train = train.drop("bacteria_name", 1)
df_train = df_train.drop("susceptibility", 1)
all_cols = df_train.columns
for col in all_cols:
    if df_train[col].nunique()<2:
        df_train = df_train.drop(col, 1)
all_cols = df_train.columns

# %%
len(all_cols)
# Out:
# 7

# %% [markdown]
# #### Breaking Into 3 Types of Columns: Binary, Categorical and Other (Ordinal or Continous)

# %%
categorical_vars = [ ]
continuous_vars = [ ]
categorical_binary_vars = [ ]

for col in all_cols:
    if df_train[col].nunique()==2:
        categorical_binary_vars.append(col)
    else:
        if df_train[col].dtypes=='object':
            categorical_vars.append(col)
        else:
            continuous_vars.append(col)

# %%
print ("categorical binary vars: ", len(categorical_binary_vars))
print ("categorical non binary vars: ", len(categorical_vars))
print ("continuous vars: ", len(continuous_vars))
# Out:
# categorical binary vars:  1
# categorical non binary vars:  3
# continuous vars:  3

# %%
all_categorical_vars = categorical_binary_vars + categorical_vars
print ("all categorical vars: ", len(all_categorical_vars))
# Out:
# all categorical vars:  4

# %% [markdown]
# #### Displaying Number of Unique Values in Each Categorical Variable Column

# %%
for cat_var in all_categorical_vars:
    print (cat_var,":", df_train[cat_var].nunique())
# Out:
# sex : 2
# device : 7
# comorbidity : 19
# antibiotic_name : 29

# %% [markdown]
# #### Creating Training and Validation Data

# %%
df_tr = df_train[:120000]
df_val = df_train[120000:]

# %%
Y_train  = train_labels[:120000]
Y_val  = train_labels[120000: ]

# %% [markdown]
# # Categorical Embedding

# %% [markdown]
# #### Printing Two Different Types of Variables Namely Categorical and Continuous/Ordinal

# %%
print(all_categorical_vars)
print(continuous_vars)
# Out:
# ['sex', 'device', 'comorbidity', 'antibiotic_name']
# ['age', 'num_prev_adm', 'interval']

# %% [markdown]
# #### Preprocessing Training and Validation Data

# %%
def preprocessing(X_train):
    input_list_train = []
    #the cols to be embedded: rescaling to range [0, # values)
    for c in all_categorical_vars:
        vals = np.asarray(X_train[c].tolist())
        vals = pd.factorize(vals)[0]
        input_list_train.append(np.asarray(vals))
        """
        This below is another method to do this:
        val_map = {}
        for i in range(len(raw_vals)):
            val_map[raw_vals[i]] = i       
        input_list_train.append(X_train[c].map(val_map).values)
        """
    #the rest of the columns
    input_list_train.append(X_train[continuous_vars].values)
    return input_list_train

# %%
df_tr_modified = preprocessing(df_tr)
df_val_modified = preprocessing(df_val)

# %% [markdown]
# #### As Expected, The Proceesed Training DataFrame has 5 Elements Becasue We had 4 Categorical Columns and One for Other (Continous/Ordinal) Columns

# %%
len(df_tr_modified)
# Out:
# 5

# %% [markdown]
# #### The Embedding Size is Set According to the Rule As Suggested by fast.ai Course and Entity Embedding Paper

# %% [markdown]
# Embedding_size  = integer value of min(ceiling(no of unique categories/2) , 50)

# %% [markdown]
# #### Each Model will be Appended to a List Named Models

# %%
# %%html
# <p style="color:red">Since Merge is Deprecated in Keras 2.2.2 We Shift to Functional API Rather Than Using Sequential Model</p>
# Out:
# <p style="color:red">Since Merge is Deprecated in Keras 2.2.2 We Shift to Functional API Rather Than Using Sequential Model</p>

# %%
models=[]
inputs=[]
embeddings=[]
functional_models=[]

# %%
# %%html
# <p style="color:red">Function to Convert Sequential Model to Functional API Model</p>
# Out:
# <p style="color:red">Function to Convert Sequential Model to Functional API Model</p>

# %%
def get_functional(model):
    input_layer = Input(batch_shape=model.layers[0].input_shape)
    prev_layer = input_layer
    for layer in model.layers:
        prev_layer = layer(prev_layer)
    functional_model = keras.models.Model([input_layer], [prev_layer])
    return input_layer, prev_layer, functional_model

# %% [markdown]
# #### Following Code Adds an Embedding Network for Each of the Catgeoriacal Variables

# %%
for variable in all_categorical_vars:
    print("For categorical column: ", variable)
    print("----------------------------------------------------------------------")
    model = Sequential()
    no_of_unique_categories  = df_train[variable].nunique()
    print("Number of unique categories: ",no_of_unique_categories)
    embedding_size = min(np.ceil(no_of_unique_categories/2), 50)
    embedding_size = int(embedding_size)
    print("Embedding size set as: ", embedding_size)
    model.add(Embedding(no_of_unique_categories+1, embedding_size, name=variable+'_embedding', input_length = 1))
    model.add(Reshape(target_shape=([embedding_size])))
    print(model.summary())
    input_layer, embedding, functional_model = get_functional(model)
    models.append(model)
    functional_models.append(functional_model)
    inputs.append(input_layer)
    embeddings.append(embedding)
# Out:
# For categorical column:  sex
# ----------------------------------------------------------------------
# Number of unique categories:  2
# Embedding size set as:  1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sex_embedding (Embedding)    (None, 1, 1)              3
# _________________________________________________________________
# reshape_5 (Reshape)          (None, 1)                 0
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# None
# For categorical column:  device
# ----------------------------------------------------------------------
# Number of unique categories:  7
# Embedding size set as:  4
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# device_embedding (Embedding) (None, 1, 4)              32
# _________________________________________________________________
# reshape_6 (Reshape)          (None, 4)                 0
# =================================================================
# Total params: 32
# Trainable params: 32
# Non-trainable params: 0
# _________________________________________________________________
# None
# For categorical column:  comorbidity
# ----------------------------------------------------------------------
# Number of unique categories:  19
# Embedding size set as:  10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# comorbidity_embedding (Embed (None, 1, 10)             200
# _________________________________________________________________
# reshape_7 (Reshape)          (None, 10)                0
# =================================================================
# Total params: 200
# Trainable params: 200
# Non-trainable params: 0
# _________________________________________________________________
# None
# For categorical column:  antibiotic_name
# ----------------------------------------------------------------------
# Number of unique categories:  29
# Embedding size set as:  15
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# antibiotic_name_embedding (E (None, 1, 15)             450
# _________________________________________________________________
# reshape_8 (Reshape)          (None, 15)                0
# =================================================================
# Total params: 450
# Trainable params: 450
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# #### Once the Embedding for Categorical Columns are Made, We Add Another Single Model for All the Continuous Variables and Add it to the Models List

# %%
model_rest = Sequential()
model_rest.add(Dense(16, input_shape = [3]))
model_rest.summary() 
input_layer_rest, embedding_rest, functional_model_rest = get_functional(model_rest)
models.append(model_rest)
functional_models.append(functional_model_rest)
inputs.append(input_layer_rest)
embeddings.append(embedding_rest)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 16)                64
# =================================================================
# Total params: 64
# Trainable params: 64
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Our Models List will Contain (Number of categorical variables)+1 Models, where Number of categorical variables = 15

# %%
models
# Out:
# [<keras.engine.sequential.Sequential at 0x126c295c0>,
#  <keras.engine.sequential.Sequential at 0x126c296a0>,
#  <keras.engine.sequential.Sequential at 0x126c51438>,
#  <keras.engine.sequential.Sequential at 0x126bd5278>,
#  <keras.engine.sequential.Sequential at 0x107b86b00>]

# %%
functional_models
# Out:
# [<keras.engine.training.Model at 0x126c29780>,
#  <keras.engine.training.Model at 0x126c513c8>,
#  <keras.engine.training.Model at 0x126bd5320>,
#  <keras.engine.training.Model at 0x1266a1198>,
#  <keras.engine.training.Model at 0x12666fe48>]

# %% [markdown]
# #### Finally We Merge All the Models Present into a Single Model Using Concat Method which Places the Models One After the Other

# %%
input_layer_full = Concatenate()(embeddings)

# %% [markdown]
# #### With Input Layers and Embedding Layers Done We can Build on Those as Any Other keras Functional Model.

# %% [markdown]
# Adding a few layers below

# %%
input_layer_full = Dense(128, activation='relu')(input_layer_full)
input_layer_full = Dropout(.5)(input_layer_full)
input_layer_full = Dense(64, activation='relu')(input_layer_full)
input_layer_full = Dropout(.25)(input_layer_full)
input_layer_full = Dense(32, activation='relu')(input_layer_full)
input_layer_full = Dropout(.15)(input_layer_full)
output = Dense(1, activation='sigmoid')(input_layer_full)

# %% [markdown]
# #### Creating the Full Model with All Variables

# %%
full_model = Model(inputs, output)

# %%
full_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
full_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# sex_embedding (Embedding)       (None, 1, 1)         3           input_6[0][0]
# __________________________________________________________________________________________________
# device_embedding (Embedding)    (None, 1, 4)         32          input_7[0][0]
# __________________________________________________________________________________________________
# comorbidity_embedding (Embeddin (None, 1, 10)        200         input_8[0][0]
# __________________________________________________________________________________________________
# antibiotic_name_embedding (Embe (None, 1, 15)        450         input_9[0][0]
# __________________________________________________________________________________________________
# input_10 (InputLayer)           (None, 3)            0
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1)            0           sex_embedding[1][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 4)            0           device_embedding[1][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 10)           0           comorbidity_embedding[1][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 15)           0           antibiotic_name_embedding[1][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 16)           64          input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 46)           0           reshape_5[1][0]
#                                                                  reshape_6[1][0]
#                                                                  reshape_7[1][0]
#                                                                  reshape_8[1][0]
#                                                                  dense_6[1][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          6016        concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 128)          0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 64)           8256        dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64)           0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 32)           2080        dropout_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32)           0           dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1)            33          dropout_6[0][0]
# ==================================================================================================
# Total params: 17,134
# Trainable params: 17,134
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Model Training and Validation

# %%
from keras.utils.np_utils import to_categorical
Y_train = Y_train.apply(lambda x: 1 if x=='S' else 0)
Y_val = Y_val.apply(lambda x: 1 if x=='S' else 0)
Y_train_cat = to_categorical(Y_train.tolist())
Y_val_cat = to_categorical(Y_val.tolist())

# %%
full_model.fit(df_tr_modified, Y_train_cat)
# Out:
# Epoch 1/1
# 120000/120000 [==============================] - 11s 92us/step - loss: 0.0020 - acc: 0.9996

# %%
full_model.evaluate(df_val_modified, Y_val_cat)
# Out:
# 81257/81257 [==============================] - 2s 31us/step
# [1.7898806128717559e-07, 1.0]

# %% [markdown]
# #### Plot Categorical Embeddings with Categories>2

# %%
from sklearn import manifold
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
antibiotic_categories = df_train['antibiotic_name'].unique().tolist()
antibiotic_embedding = full_model.get_layer('antibiotic_name_embedding').get_weights()[0]
antibiotic_embedding
# Out:
# array([[ 1.30503252e-02,  9.93953086e-03, -3.32715549e-02,
#          5.55762462e-02,  2.09275801e-02,  2.09445413e-02,
#         -4.72599231e-02,  2.26016659e-02,  1.88734233e-02,
#         -1.50200613e-02, -2.85169631e-02, -4.86056916e-02,
#         -2.52177287e-02, -5.55277355e-02, -4.50309552e-02],
#        [ 1.51368231e-02,  1.83424521e-02, -4.02826741e-02,
#          2.52446271e-02, -8.54822770e-02, -2.84554251e-02,
#          5.94888590e-02,  7.80445486e-02,  4.18290198e-02,
#         -3.53010744e-02,  7.08054155e-02,  1.73862241e-02,
#          4.22067977e-02,  1.49431387e-02,  2.72499933e-03],
#        [ 4.10491154e-02,  3.00877728e-02,  4.20068651e-02,
#          3.09235994e-02, -1.58377981e-03, -3.08568422e-02,
#         -1.56455170e-02,  2.56504472e-02,  3.40747498e-02,
#          5.23105524e-02,  1.53962793e-02,  3.26813497e-02,
#          1.62534118e-02, -1.08521897e-02, -2.58514509e-02],
#        [-1.15106991e-02, -1.72569267e-02,  9.83975735e-03,
#          3.36064361e-02, -8.53346959e-02,  2.71721538e-02,
#          8.77895672e-03, -1.72769148e-02,  6.43826127e-02,
#          4.53363098e-02,  3.75444070e-02, -2.53629964e-03,
#         -1.09708998e-02, -7.20975862e-04, -5.07115759e-02],
#        [-5.51710948e-02, -2.05790140e-02, -1.37841497e-02,
#          5.87995872e-02, -5.07085882e-02, -1.88851468e-02,
#          4.63424297e-03,  1.13515472e-02,  1.03741549e-02,
#         -3.64312879e-03,  2.51666345e-02, -2.63221152e-02,
#         -8.72392673e-03,  2.73179691e-02, -1.55059583e-02],
#        [ 1.85408834e-02,  3.39447893e-02, -5.51695935e-02,
#         -3.68513763e-02, -3.87765653e-02, -2.52012126e-02,
#          3.76418345e-02,  5.74140251e-02, -2.04158816e-02,
#         -3.85703519e-02,  1.06737642e-02, -1.90810207e-02,
#          1.06792422e-02,  3.12065016e-02, -2.91044973e-02],
#         -2.44095363e-02,  1.17742205e-02, -4.42997105e-02,
#          3.91175374e-02,  2.20635836e-03,  2.42571607e-02,
#          3.98724200e-03],
#        [-7.26391081e-05, -3.32350582e-02, -4.01390754e-02,
#          3.78953889e-02,  1.15305316e-02,  2.75793187e-02,
#         -2.61456426e-02,  3.25515643e-02,  1.29507631e-02,
#          2.16705212e-03],
#        [-1.50977622e-03, -1.33121881e-04, -3.58966552e-02,
#          3.09853349e-02,  8.34080484e-03, -4.96714935e-02,
#          7.88708776e-03,  6.61778776e-03,  1.06791910e-02,
#         -7.27636814e-02],
#        [ 8.41626301e-02, -1.06335893e-01,  5.22389412e-02,
#          1.33566007e-01,  5.63072041e-02, -8.81764293e-02,
#         -6.78701997e-02,  8.09552222e-02, -2.80471928e-02,
#         -7.77982548e-02],
#        [ 1.08850666e-03,  7.65085267e-03, -2.22869664e-02,
#         -1.84618346e-02, -1.02623021e-02, -6.70417165e-03,
#          4.60562631e-02, -4.57642488e-02,  1.86911616e-02,
#          3.95223834e-02],
#        [-1.42713217e-02,  5.07744104e-02, -2.15466483e-03,
#          4.41160500e-02, -4.02072445e-02,  2.09323131e-02,
#         -1.39145218e-02, -7.79226713e-04, -2.32759882e-02,
#          6.85420912e-03],
#        [ 3.10795568e-02, -4.54209819e-02, -4.49306481e-02,
#         -2.36274954e-02, -3.63585837e-02,  3.32362093e-02,
#         -4.68552709e-02, -1.59852020e-02, -6.85824081e-03,
#         -1.80501454e-02]], dtype=float32)

# %%
tsne = manifold.TSNE(init='pca', random_state=0, method='exact')
Y = tsne.fit_transform(comorbidity_embedding)
plt.figure(figsize=(18,18))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(comorbidity_categories):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-20, 8), textcoords = 'offset points')

# %% [markdown]
# #### Plotting Pairwise Distances for Antibiotics (Embedding Vectors)

# %%
from scipy.spatial import distance
distances = pd.DataFrame(columns=['Antibiotic1', 'Antibiotic2', 'Distance'])
ab1=[]
ab2=[]
dist=[]
for i in range(len(antibiotic_categories)):
    for j in range(len(antibiotic_categories)):
        if j!=i:
            ab1.append(antibiotic_categories[i])
            ab2.append(antibiotic_categories[j])
            dist.append(distance.euclidean(antibiotic_embedding[i].reshape(-1, 1), antibiotic_embedding[j].reshape(-1, 1)))

distances['Antibiotic1'] = pd.Series(ab1)
distances['Antibiotic2'] = pd.Series(ab2)
distances['Distance'] = pd.Series(dist)
distances = distances.sort_values(by=['Distance']).reset_index(drop=True)
distances
# Out:
#                    Antibiotic1                Antibiotic2  Distance
# 0                   Daptomycin              Ciprofloxacin  0.099221
# 1                Ciprofloxacin                 Daptomycin  0.099221
# 2                 Erythromycin                 Tobramycin  0.099589
# 3                   Tobramycin               Erythromycin  0.099589
# 4                 Erythromycin                 Ampicillin  0.105910
# 5                   Ampicillin               Erythromycin  0.105910
# 6                   Cefuroxime                  Cefazolin  0.110991
# 7                    Cefazolin                 Cefuroxime  0.110991
# 8                  Ceftazidime                Ceftriaxone  0.111604
# 9                  Ceftriaxone                Ceftazidime  0.111604
# 10                    Amikacin               Piperacillin  0.114411
# 11                Piperacillin                   Amikacin  0.114411
# 12                    Cefepime                 Vancomycin  0.114630
# 13                  Vancomycin                   Cefepime  0.114630
# 14                  Ampicillin                 Penicillin  0.117605
# 15                  Penicillin                 Ampicillin  0.117605
# 16              Co-Trimoxazole               Penicillin G  0.118190
# 17                Penicillin G             Co-Trimoxazole  0.118190
# 18                 Ceftriaxone               Erythromycin  0.118672
# 19                Erythromycin                Ceftriaxone  0.118672
# 20                Erythromycin                 Cefuroxime  0.119579
# 21                  Cefuroxime               Erythromycin  0.119579
# 22             Chloramphenicol                Ceftazidime  0.120150
# 23                 Ceftazidime            Chloramphenicol  0.120150
# 24                  Cefuroxime                Ceftazidime  0.120207
# 25                 Ceftazidime                 Cefuroxime  0.120207
# 26                    Amikacin                 Daptomycin  0.120737
# 27                  Daptomycin                   Amikacin  0.120737
# 28                  Vancomycin             Co-Trimoxazole  0.121431
# 29              Co-Trimoxazole                 Vancomycin  0.121431
# ..                         ...                        ...       ...
# 782                 Vancomycin             Nitrofurantoin  0.250137
# 783             Nitrofurantoin                 Vancomycin  0.250137
# 784                  Linezolid                   Cefepime  0.251953
# 785                   Cefepime                  Linezolid  0.251953
# 786             Nitrofurantoin              Tetracyclline  0.252531
# 787              Tetracyclline             Nitrofurantoin  0.252531
# 788                  Oxacillin                 Gentamicin  0.252901
# 789                 Gentamicin                  Oxacillin  0.252901
# 790                 Gentamicin                Ceftazidime  0.252927
# 791                Ceftazidime                 Gentamicin  0.252927
# 792                Clindamycin                 Gentamicin  0.257893
# 793                 Gentamicin                Clindamycin  0.257893
# 794                 Gentamicin                   Imipenem  0.258843
# 795                   Imipenem                 Gentamicin  0.258843
# 796                  Meropenem                  Linezolid  0.260418
# 797                  Linezolid                  Meropenem  0.260418
# 798                 Gentamicin               Penicillin G  0.260439
# 799               Penicillin G                 Gentamicin  0.260439
# 800                 Rifampicin                 Gentamicin  0.269784
# 801                 Gentamicin                 Rifampicin  0.269784
# 802                  Linezolid                 Gentamicin  0.271441
# 803                 Gentamicin                  Linezolid  0.271441
# 804            Chloramphenicol                 Gentamicin  0.274443
# 805                 Gentamicin            Chloramphenicol  0.274443
# 806  Piperacillin + Tazobactam                 Gentamicin  0.276268
# 807                 Gentamicin  Piperacillin + Tazobactam  0.276268
# 808             Nitrofurantoin                 Gentamicin  0.283182
# 809                 Gentamicin             Nitrofurantoin  0.283182
# 810     Ampicillin + Sulbactam                 Gentamicin  0.290129
# 811                 Gentamicin     Ampicillin + Sulbactam  0.290129
#
# [812 rows x 3 columns]

# %%
import seaborn as sns; sns.set(color_codes=True)
g = sns.distplot(distances.Distance)
g = sns.pairplot(distances, size=7)
g = sns.pairplot(distances, size=7, diag_kind='kde')
# Out:
# /anaconda2/envs/py36/lib/python3.6/site-packages/scipy/stats/stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /anaconda2/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
distances.Distance = distances.Distance.apply(lambda x: np.round(x, decimals=2))
plt.figure(figsize=(60, 35))
sns.set(font_scale=1.8) 
pivot = distances.pivot(index='Antibiotic1', columns='Antibiotic2', values='Distance')
ax = sns.heatmap(pivot,annot=True)
plt.show()
